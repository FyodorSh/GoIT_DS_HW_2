# %% [markdown]
# Прочитайте csv файл (використовуйте функцію read_csv)

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

drive.mount('/content/drive/')

bestsellers = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/bestsellers with categories.csv')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# Виведіть перші п'ять рядків (використовується функція head)

# %%
bestsellers.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %% [markdown]
# Виведіть розміри датасету (використовуйте атрибут shape)

# %%
bestsellers.shape
# Out:
# (550, 7)

# %% [markdown]
# **Відповідь:** *Про скільки книг зберігає дані датасет?* - **351**

# %%
bestsellers['Name'].nunique()
# Out:
# 351

# %%
bestsellers.columns = ['name', 'author', 'user_rating', 'reviews', 'price', 'year', 'genre']
bestsellers
# Out:
#                                                   name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        author  user_rating  reviews  price  year        genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %% [markdown]
# Перевірте, чи у всіх рядків вистачає даних: виведіть кількість пропусків (na) у кожному зі стовпців (використовуйте функції isna та sum)

# %%
bestsellers.isna().sum()
# Out:
# name           0
# author         0
# user_rating    0
# reviews        0
# price          0
# year           0
# genre          0
# dtype: int64

# %% [markdown]
# **Відповідь:** *Чи є в якихось змінних пропуски? (Так / ні)* - **Ні**

# %% [markdown]
# Перевірте, які є унікальні значення в колонці genre (використовуйте функцію unique)

# %%
bestsellers["genre"].unique()
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %% [markdown]
# **Відповідь:** *Які є унікальні жанри?* - **Non Fiction та Fiction**

# %% [markdown]
# Тепер подивіться на розподіл цін: побудуйте діаграму (використовуйте kind='hist')

# %%
ax = bestsellers['price'].plot.hist(bins=30)

# %% [markdown]
# Визначте, яка ціна у нас максимальна, мінімальна, середня, медіанна (використовуйте функції max, min, mean, median)

# %%
max = bestsellers['price'].max()
min = bestsellers['price'].min()
mean = bestsellers['price'].mean()
median = bestsellers['price'].median()

print(f'{max=} {min=} {mean=} {median=}')
# Out:
# max=105 min=0 mean=13.1 median=11.0

# %% [markdown]
# * **Відповідь:** *Максимальна ціна?* - **105**
# * **Відповідь:** *Мінімальна ціна?* - **0**
# * **Відповідь:** *Середня ціна?* - **13.1**
# * **Відповідь:** *Медіанна ціна?* - **11**

# %% [markdown]
# **Відповідь:** *Який рейтинг у датасеті найвищий?* - **4.9**

# %%
max_rate = bestsellers['user_rating'].max()
max_rate
# Out:
# 4.9

# %% [markdown]
# **Відповідь:** *Скільки книг мають такий рейтинг?* - **28**

# %%
max_rate_rows = bestsellers.loc[bestsellers['user_rating'] == max_rate]
max_rate_rows['name'].nunique()
# Out:
# 28

# %% [markdown]
# **Відповідь:** *Яка книга має найбільше відгуків?* -
# 'Brown Bear, Brown Bear, What Do You See?',
#        'Dog Man and Cat Kid: From the Creator of Captain Underpants (Dog Man #4)',
#        'Dog Man: A Tale of Two Kitties: From the Creator of Captain Underpants (Dog Man #3)',
#        'Dog Man: Brawl of the Wild: From the Creator of Captain Underpants (Dog Man #6)',
#        'Dog Man: Fetch-22: From the Creator of Captain Underpants (Dog Man #8)',
#        'Dog Man: For Whom the Ball Rolls: From the Creator of Captain Underpants (Dog Man #7)',
#        'Dog Man: Lord of the Fleas: From the Creator of Captain Underpants (Dog Man #5)',
#        'Goodnight, Goodnight Construction Site (Hardcover Books for Toddlers, Preschool Books for Kids)',
#        'Hamilton: The Revolution',
#        'Harry Potter and the Chamber of Secrets: The Illustrated Edition (Harry Potter, Book 2)',
#        'Harry Potter and the Goblet of Fire: The Illustrated Edition (Harry Potter, Book 4) (4)',
#        'Harry Potter and the Prisoner of Azkaban: The Illustrated Edition (Harry Potter, Book 3)',
#        "Harry Potter and the Sorcerer's Stone: The Illustrated Edition (Harry Potter, Book 1)",
#        'Humans of New York : Stories',
#        'Jesus Calling: Enjoying Peace in His Presence (with Scripture References)',
#        'Last Week Tonight with John Oliver Presents A Day in the Life of Marlon Bundo (Better Bundo Book, LGBT Children\x92s Book)',
#        'Little Blue Truck', 'Obama: An Intimate Portrait',
#        "Oh, the Places You'll Go!",
#        'Rush Revere and the Brave Pilgrims: Time-Travel Adventures with Exceptional Americans (1)',
#        'Rush Revere and the First Patriots: Time-Travel Adventures With Exceptional Americans (2)',
#        'Strange Planet (Strange Planet Series)',
#        'The Legend of Zelda: Hyrule Historia', 'The Magnolia Story',
#        'The Very Hungry Caterpillar', 'The Wonderful Things You Will Be',
#        'Unfreedom of the Press',
#        'Wrecking Ball (Diary of a Wimpy Kid Book 14)'

# %%
max_rate_rows['name'].unique()
# Out:
# array(['Brown Bear, Brown Bear, What Do You See?',
#        'Dog Man and Cat Kid: From the Creator of Captain Underpants (Dog Man #4)',
#        'Dog Man: A Tale of Two Kitties: From the Creator of Captain Underpants (Dog Man #3)',
#        'Dog Man: Brawl of the Wild: From the Creator of Captain Underpants (Dog Man #6)',
#        'Dog Man: Fetch-22: From the Creator of Captain Underpants (Dog Man #8)',
#        'Dog Man: For Whom the Ball Rolls: From the Creator of Captain Underpants (Dog Man #7)',
#        'Dog Man: Lord of the Fleas: From the Creator of Captain Underpants (Dog Man #5)',
#        'Goodnight, Goodnight Construction Site (Hardcover Books for Toddlers, Preschool Books for Kids)',
#        'Hamilton: The Revolution',
#        'Harry Potter and the Chamber of Secrets: The Illustrated Edition (Harry Potter, Book 2)',
#        'Harry Potter and the Goblet of Fire: The Illustrated Edition (Harry Potter, Book 4) (4)',
# ...

# %% [markdown]
# **Відповідь:** *З тих книг, що потрапили до Топ-50 у 2015 році, яка книга найдорожча (можна використати проміжний датафрейм)?* - Diagnostic and Publication Manual of the American Psychologic..

# %%
best_2015 = bestsellers.loc[bestsellers['year'] == 2015]
max_2015 = best_2015['price'].max()
best_2015.loc[best_2015['price'] == max_2015]
# Out:
#                                                   name  \
# 277  Publication Manual of the American Psychologic...
#
#                                  author  user_rating  reviews  price  year  \
# 277  American Psychological Association          4.5     8580     46  2015
#
#            genre
# 277  Non Fiction

# %% [markdown]
# **Відповідь:** *Скільки книг жанру Fiction потрапили до Топ-50 у 2010 році (використовуйте &)?* - **20**

# %%
bestsellers.loc[(bestsellers['year'] == 2010) & (bestsellers['genre'] == 'Fiction')]['name'].nunique()
# Out:
# 20

# %% [markdown]
# **Відповідь:** *Скільки книг з рейтингом 4.9 потрапило до рейтингу у 2010 та 2011 роках (використовуйте | або функцію isin)* - 1

# %%
bestsellers.loc[((bestsellers['year'] == 2010) | (bestsellers['year'] == 2011))& (bestsellers['user_rating'] == 4.9)]['name'].nunique()
# Out:
# 1

# %% [markdown]
# І насамкінець, давайте відсортуємо за зростанням ціни всі книги, які потрапили до рейтингу в 2015 році і коштують дешевше за 8 доларів (використовуйте функцію sort_values).

# %%
best_2015.loc[best_2015['price'] < 8].sort_values('price')
# Out:
#                                                   name              author  \
# 507                              To Kill a Mockingbird          Harper Lee
# 210                      Laugh-Out-Loud Jokes for Kids         Rob Elliott
# 206                         Knock-Knock Jokes for Kids         Rob Elliott
# 111                                    First 100 Words        Roger Priddy
# 123                               Giraffes Can't Dance       Giles Andreae
# 54   Creative Haven Creative Cats Coloring Book (Ad...     Marjorie Sarnat
# 63                      Dear Zoo: A Lift-the-Flap Book        Rod Campbell
# 89   Dover Creative Haven Art Nouveau Animal Design...         Marty Noble
# 478                        The Very Hungry Caterpillar          Eric Carle
# 201  Killing Reagan: The Violent Assault That Chang...       Bill O'Reilly
# 28                        Baby Touch and Feel: Animals                  DK
# ...

# %% [markdown]
# **Відповідь:** *Яка книга остання у відсортованому списку?* - **Old School (Diary of a Wimpy Kid #10)**

# %% [markdown]
# Для початку давайте подивимося на максимальну та мінімальну ціни для кожного з жанрів (використовуйте функції groupby та agg, для підрахунку мінімальних та максимальних значень використовуйте max та min). Не беріть усі стовпці, виберіть тільки потрібні вам

# %%
bestsellers.groupby('genre').agg({'price' : ['min', 'max']})
# Out:
#             price
#               min  max
# genre
# Fiction         0   82
# Non Fiction     0  105

# %% [markdown]
# Відповідь: Максимальна ціна для жанру Fiction: 82
#
# Відповідь: Мінімальна ціна для жанру Fiction: 0
#
# Відповідь: Максимальна ціна для жанру Non Fiction: 105
#
# Відповідь: Мінімальна ціна для жанру Non Fiction: 0

# %% [markdown]
# Тепер створіть новий датафрейм, який вміщатиме кількість книг для кожного з авторів (використовуйте функції groupby та agg, для підрахунку кількості використовуйте count). Не беріть усі стовпці, виберете тільки потрібні

# %%
authors = bestsellers.groupby('author').agg(book_count = ('author', 'count'))
authors
# Out:
#                             book_count
# author
# Abraham Verghese                     2
# Adam Gasiewski                       1
# Adam Mansbach                        1
# Adir Levy                            1
# Admiral William H. McRaven           1
# ...                                ...
# Walter Isaacson                      3
# William Davis                        2
# William P. Young                     2
# Wizards RPG Team                     3
# Zhi Gang Sha                         2
#
# [248 rows x 1 columns]

# %%
authors.shape
# Out:
# (248, 1)

# %% [markdown]
# Відповідь: Якої розмірності вийшла таблиця? Відповідь: (248, 1)
#
# Відповідь: Який автор має найбільше книг? Відповідь: Jeff Kinney
#
# Відповідь: Скільки книг цього автора? Відповідь: 12

# %% [markdown]
# Тепер створіть другий датафрейм, який буде вміщати середній рейтинг для кожного автора (використовуйте функції groupby та agg, для підрахунку середнього значення використовуйте mean). Не беріть усі стовпці, виберете тільки потрібні

# %%
author_rating = bestsellers.groupby('author').agg(mean_rating = ('user_rating' ,'mean'))
author_rating
# Out:
#                             mean_rating
# author
# Abraham Verghese               4.600000
# Adam Gasiewski                 4.400000
# Adam Mansbach                  4.800000
# Adir Levy                      4.800000
# Admiral William H. McRaven     4.700000
# ...                                 ...
# Walter Isaacson                4.566667
# William Davis                  4.400000
# William P. Young               4.600000
# Wizards RPG Team               4.800000
# Zhi Gang Sha                   4.600000
#
# [248 rows x 1 columns]

# %% [markdown]
# Відповідь: У якого автора середній рейтинг мінімальний? Відповідь: Donna Tartt
#
# Відповідь: Який у цього автора середній рейтинг? Відповідь: 3.9

# %% [markdown]
# З'єднайте останні два датафрейми так, щоб для кожного автора було видно кількість книг та середній рейтинг (Використовуйте функцію concat з параметром axis=1). Збережіть результат у змінну

# %%
rates_books = pd.concat([author_rating, authors], axis=1)
rates_books
# Out:
#                             mean_rating  book_count
# author
# Abraham Verghese               4.600000           2
# Adam Gasiewski                 4.400000           1
# Adam Mansbach                  4.800000           1
# Adir Levy                      4.800000           1
# Admiral William H. McRaven     4.700000           1
# ...                                 ...         ...
# Walter Isaacson                4.566667           3
# William Davis                  4.400000           2
# William P. Young               4.600000           2
# Wizards RPG Team               4.800000           3
# Zhi Gang Sha                   4.600000           2
#
# [248 rows x 2 columns]

# %% [markdown]
# Відсортуйте датафрейм за зростаючою кількістю книг та зростаючим рейтингом (використовуйте функцію sort_values)

# %%
rates_books.sort_values(by=['book_count','mean_rating'], ascending=False)
# Out:
#                                     mean_rating  book_count
# author
# Jeff Kinney                            4.800000          12
# Rick Riordan                           4.772727          11
# Gary Chapman                           4.736364          11
# Suzanne Collins                        4.663636          11
# American Psychological Association     4.500000          10
# ...                                         ...         ...
# Rob Bell                               4.200000           1
# Chris Cleave                           4.100000           1
# Ian K. Smith M.D.                      4.100000           1
# Pierre Dukan                           4.100000           1
# Muriel Barbery                         4.000000           1
#
# [248 rows x 2 columns]

# %% [markdown]
# Відповідь: Який автор перший у списку? - Jeff Kinney

# %% [markdown]
# Візуалізація

# %%
ax = author_rating['mean_rating'].plot.hist(bins=10)

# %%
genre_count = bestsellers.groupby('genre').agg(genre_count = ('price' , 'count'))
plot = genre_count.plot.pie(y='genre_count', figsize=(10, 10), legend=True)

# %%
df = pd.DataFrame({'x': bestsellers['price'],
                   'y': bestsellers['reviews']})
ax = df.plot.hexbin(x='x', y='y', gridsize=30)
